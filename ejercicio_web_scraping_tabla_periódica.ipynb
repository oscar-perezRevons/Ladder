# %% [markdown]
# **Ejercicio web scraping**
#
# Extraer de la página web "__[Tabla periódica de los elementos](https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos)__" los siguientes datos en un archivo CSV:
#
# - El nombre
# - El Símbolo
# - El número atómico
# - El enlace a la página en Wikipedia
# - La categoría
#
# Por ejemplo:
# ```
# nombre,simbolo,numero_atomico,url,categoria
# Ununennio,Uue,119,https://es.wikipedia.org/wiki/Ununennio,Metales-Alcalinos
# ```

# %%
print(pagina.center.find(name="td", attrs={"a":"H"}))
# Out:
# None

# %%
import requests
from bs4 import BeautifulSoup

respuesta = requests.get("http://localhost:8000/Tabla_periódica_de_los_elementos.html")
pagina = BeautifulSoup(respuesta.text, "html.parser")
pagina.center
# Out:
# <center>
# <table border="0" cellpadding="0" cellspacing="3" width="80%">
# <caption><b>Tabla periÃ³dica de los elementos</b><sup class="reference separada" id="cite_ref-13"><a href="https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos#cite_note-13"><span class="corchete-llamada">[</span>12<span class="corchete-llamada">]</span></a></sup>â
# </caption>
# <tbody><tr>
# <td align="right" bgcolor="#FFFFFF" width="8%"><b><a href="https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos#Grupos">Grupo</a></b>
# </td>
# <td align="center" bgcolor="#FFFFFF" width="5%"><b><a href="https://es.wikipedia.org/wiki/Alcalino" title="Alcalino">1</a></b>
# </td>
# <td align="center" bgcolor="#FFFFFF" width="5%"><b><a class="mw-redirect" href="https://es.wikipedia.org/wiki/Alcalinot%C3%A9rreo" title="AlcalinotÃ©rreo">2</a></b>
# </td>
# ...
